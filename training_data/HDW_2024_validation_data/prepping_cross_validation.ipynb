# %%
import pandas as pd

# %%
df_lucia = pd.read_excel("Lucia Annotations 6_20.xlsx")

# %%
df_sada = pd.read_excel("Sada_annotations.xlsx")

# %%
import pandas as pd

# Load the Excel file with three sheets
excel_file = 'eric_mental.xlsx'

# Read the Excel file
xls = pd.ExcelFile(excel_file)

# Iterate through each sheet and save it as an individual Excel file
for sheet_name in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet_name)
    output_filename = f'{sheet_name}.xlsx'
    df.to_excel(output_filename, index=False)

# %%
df1 = pd.read_excel("eric_mental.xlsx")

# %%
df2 = pd.read_excel("eric_behavior.xlsx")

# %%
df3 = pd.read_excel("eric_null.xlsx")

# %%
combined_df = df1.merge(df2, on=["text", "designation", "file", "sub-categories", "notes"], how='outer')
combined_df = combined_df.merge(df3, on=["text", "designation", "file", "sub-categories", "notes"], how='outer')

# %%
combined_df.columns
# Out:
# Index(['text', 'designation', 'file', 'sub-categories', 'embedded?', 'notes',
#        'Unnamed: 6_x', 'interaction?', 'Unnamed: 6_y', '?'],
#       dtype='object')

# %%
combined_df = combined_df.drop('Unnamed: 6_x', axis=1)

# %%
combined_df = combined_df.drop('Unnamed: 6_y', axis=1)

# %%
combined_df.head()
# Out:
#                                                 text designation  \
# 0  That evening Mr. Utterson came home to his bac...      mental
# 1  It offended him both as a lawyer and as a love...      mental
# 2  It was a night of little ease to his toiling m...      mental
# 3  At least it would be a face worth seeing: the ...      mental
# 4                   But his fear was only momentary.      mental
#
#                        file    sub-categories embedded? notes interaction?   ?
# 0  stevenson-jekyl-1886.txt           emotion       NaN   NaN          NaN NaN
# 1  stevenson-jekyl-1886.txt           emotion       NaN   NaN          NaN NaN
# 2  stevenson-jekyl-1886.txt  emotion; thought       NaN   NaN          NaN NaN
# 3  stevenson-jekyl-1886.txt           emotion       NaN   NaN          NaN NaN
# 4  stevenson-jekyl-1886.txt           emotion       NaN   NaN          NaN NaN

# %%
combined_df.to_excel("eric_annotations.xlsx")

# %%
df_lucia.head()
# Out:
#                                                 Text Designation Subcategory  \
# 0  The father caught his son’s eye at last and ga...    behavior      facial
# 1                 The father slowly rubbed his legs.    behavior      action
# 2                 The young man looked at his watch.    behavior      facial
# 3  She directed their course back to the library ...    behavior      action
# 4  He arrived more dead than alive and lay there ...    behavior      action
#
#   ? / Secondary Interaction Embedded                File Name
# 0           NaN         yes      NaN  james-portrait-1881.txt
# 1           NaN         NaN      NaN  james-portrait-1881.txt
# 2           NaN         NaN      NaN  james-portrait-1881.txt
# 3        facial         yes      NaN  james-portrait-1881.txt
# 4           NaN         NaN      NaN  james-portrait-1881.txt

# %%
df_lucia["File Name"].unique()
# Out:
# array(['james-portrait-1881.txt', 'bronte-shirley-1849.txt',
#        'lawless-grania-1892.txt', 'macdonald-gutta-1873.txt',
#        'marryat-pirate-1836.txt', 'montgomery-misunderstood-1869.txt',
#        'lever-ride-1861.txt', 'opie-adeline-1804.txt',
#        'thackeray-lyndon-1844.txt', 'reach-leonard-1877.txt',
#        'reid-rifle-1850.txt', 'stevenson-kidnapped-1886.txt'],
#       dtype=object)

# %%
lucia_sentences = []

lucia_third = ['james-portrait-1881.txt', 'bronte-shirley-1849.txt',
       'lawless-grania-1892.txt', 'macdonald-gutta-1873.txt',
       'marryat-pirate-1836.txt', 'montgomery-misunderstood-1869.txt', 'opie-adeline-1804.txt']

for index, row in df_lucia.iterrows():
    if row["File Name"] in lucia_third:
        lucia_sentences.append(row["Text"])

# %%
lucia_sentences
# Out:
# ['The father caught his son’s eye at last and gave him a mild, responsive smile.',
#  'The father slowly rubbed his legs.',
#  'The young man looked at his watch.',
#  'She directed their course back to the library while the visitor continued to look about her.',
#  'He arrived more dead than alive and lay there for several weeks between life and death.',
#  'He had a good deal of talk with his young kinswoman when the two had been left together in the drawing-room.',
#  'In her infantine excursions to Europe she had seen only the Continent, and seen it from the nursery window;',
#  'He passed hours in the open air, sitting with folded hands like a placid, homely household god, a god of service, who had done his work and received his wages and was trying to grow used to weeks and months made up only of off-days.',
#  'She would ask nothing but questions; it is true that of these she asked a quantity.',
# ...

# %%
combined_df.head()
# Out:
#                                                 text designation  \
# 0  That evening Mr. Utterson came home to his bac...      mental
# 1  It offended him both as a lawyer and as a love...      mental
# 2  It was a night of little ease to his toiling m...      mental
# 3  At least it would be a face worth seeing: the ...      mental
# 4                   But his fear was only momentary.      mental
#
#                        file    sub-categories embedded? notes interaction?   ?
# 0  stevenson-jekyl-1886.txt           emotion       NaN   NaN          NaN NaN
# 1  stevenson-jekyl-1886.txt           emotion       NaN   NaN          NaN NaN
# 2  stevenson-jekyl-1886.txt  emotion; thought       NaN   NaN          NaN NaN
# 3  stevenson-jekyl-1886.txt           emotion       NaN   NaN          NaN NaN
# 4  stevenson-jekyl-1886.txt           emotion       NaN   NaN          NaN NaN

# %%
eric_sentences = []

eric_third = ['stevenson-jekyl-1886.txt', 'gaskell-north-1855.txt', 'wells-love-1899.txt', 'kipling-light-1891.txt', 'lamb-glenarvon-1816.txt', 'eliot-mill-1860.txt', 'disraeli-coningsby-1844.txt', 'haggard-brighteyes-1891.txt']

for index, row in combined_df.iterrows():
    if row["file"] in eric_third:
        eric_sentences.append(row["text"])

# %%
eric_sentences
# Out:
# ['That evening Mr. Utterson came home to his bachelor house in sombre spirits and sat down to dinner without relish.',
#  'It offended him both as a lawyer and as a lover of the sane and customary sides of life, to whom the fanciful was the immodest.',
#  'It was a night of little ease to his toiling mind, toiling in mere darkness and besieged by questions.',
#  'At least it would be a face worth seeing: the face of a man who was without bowels of mercy: a face which had but to show itself to raise up, in the mind of the unimpressionable Enfield, a spirit of enduring hatred.\n',
#  'But his fear was only momentary.',
#  'Cried Mr. Hyde, with a flush of anger.',
# ...

# %%
df_sada.head()
# Out:
#                                                 Text Designation subcategory  \
# 0  North, south, and west, not a casement was \nu...    behavior         NaN
# 1  That she had not taken up the position for pur...    behavior         NaN
# 2  It was to avoid listening to these voices that...    behavior         NaN
# 3  But she could not escape the conversation, try...    behavior         NaN
# 4     She knew the subject of dispute to be herself.    behavior         NaN
#
#   interactive embedded Questionable          Filename  Unnamed: 7  Unnamed: 8  \
# 0         NaN      NaN          NaN  hardy-group-1891         NaN         NaN
# 1         NaN      NaN          NaN  hardy-group-1891         NaN         NaN
# 2         NaN      NaN          NaN  hardy-group-1891         NaN         NaN
# 3         NaN      NaN          NaN  hardy-group-1891         NaN         NaN
# 4         NaN      NaN          NaN  hardy-group-1891         NaN         NaN
#
# ...

# %%
df_sada["Text"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3013 entries, 0 to 3012
# Series name: Text
# Non-Null Count  Dtype
# --------------  -----
# 2995 non-null   object
# dtypes: object(1)
# memory usage: 23.7+ KB

# %%
df_sada = df_sada[df_sada["Text"].notna()]

# %%
df_sada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2995 entries, 0 to 3012
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Text          2995 non-null   object
#  1   Designation   2406 non-null   object
#  2   subcategory   2389 non-null   object
#  3   interactive   78 non-null     object
#  4   embedded      46 non-null     object
#  5   Questionable  39 non-null     object
#  6   Filename      2995 non-null   object
#  7   Unnamed: 7    0 non-null      float64
#  8   Unnamed: 8    0 non-null      float64
#  9   Unnamed: 9    0 non-null      float64
#  10  Unnamed: 10   0 non-null      float64
#  11  Unnamed: 11   0 non-null      float64
#  12  Unnamed: 12   0 non-null      float64
#  13  Unnamed: 13   1 non-null      object
# dtypes: float64(6), object(8)
# memory usage: 351.0+ KB

# %%
texts = df_sada["Text"].tolist()

# %%
texts
# Out:
# ['North, south, and west, not a casement was \nunfastened, not a curtain undrawn; eastward, one window on the upper \nfloor was open, and a girl of twelve or thirteen was leaning over the \nsill.',
#  'That she had not taken up the position for purposes of observation \nwas apparent at a glance, for she kept her eyes covered with her hands. \n',
#  'It was to avoid listening to these voices that \nthe girl had left her little cot, thrown a cloak round her head and \nshoulders, and stretched into the night air.',
#  'But she could not escape the conversation, try as she would.',
#  'She knew the subject of dispute to be herself.',
#  "A cool feminine voice, \nher mother's, replied:",
#  'As soon as he could utter a connected sentence he \nsaid',
#  'After this there were no more words; but presently, hearing the sound of \na door opening and shutting below, the girl again looked from the window.',
# ...

# %%
sada_sentences = []

for s in texts:
    x = s.replace("\n", "")
    sada_sentences.append(x)

# %%
y = sada_sentences[1]

# %%
sada_sentences
# Out:
# ['North, south, and west, not a casement was unfastened, not a curtain undrawn; eastward, one window on the upper floor was open, and a girl of twelve or thirteen was leaning over the sill.',
#  'That she had not taken up the position for purposes of observation was apparent at a glance, for she kept her eyes covered with her hands. ',
#  'It was to avoid listening to these voices that the girl had left her little cot, thrown a cloak round her head and shoulders, and stretched into the night air.',
#  'But she could not escape the conversation, try as she would.',
#  'She knew the subject of dispute to be herself.',
#  "A cool feminine voice, her mother's, replied:",
#  'As soon as he could utter a connected sentence he said',
#  'After this there were no more words; but presently, hearing the sound of a door opening and shutting below, the girl again looked from the window.',
# ...

# %%
lucia_validation = []

# %%
lucia_validation = pd.DataFrame((eric_sentences + sada_sentences), columns=['texts'])

# %%
from sklearn.utils import shuffle
lucia_validation = shuffle(lucia_validation)

# %%
lucia_validation.head()
# Out:
#                                                   texts
# 1144  And these intimations and announcements had be...
# 4285  If there was any other expression in her eyes,...
# 2206  The Court servants desired him to stay over th...
# 2838                        And nearly a minute passed.
# 1735  It is one of those old, old towns which impres...

# %%
lucia_sentences[:10]
# Out:
# ['The father caught his son’s eye at last and gave him a mild, responsive smile.',
#  'The father slowly rubbed his legs.',
#  'The young man looked at his watch.',
#  'She directed their course back to the library while the visitor continued to look about her.',
#  'He arrived more dead than alive and lay there for several weeks between life and death.',
#  'He had a good deal of talk with his young kinswoman when the two had been left together in the drawing-room.',
#  'In her infantine excursions to Europe she had seen only the Continent, and seen it from the nursery window;',
#  'He passed hours in the open air, sitting with folded hands like a placid, homely household god, a god of service, who had done his work and received his wages and was trying to grow used to weeks and months made up only of off-days.',
#  'She would ask nothing but questions; it is true that of these she asked a quantity.',
# ...

# %%
lucia_validation = lucia_validation.reset_index(drop=True)
lucia_validation.head()
# Out:
#                                                texts
# 0  And these intimations and announcements had be...
# 1  If there was any other expression in her eyes,...
# 2  The Court servants desired him to stay over th...
# 3                        And nearly a minute passed.
# 4  It is one of those old, old towns which impres...

# %%
lucia_validation.to_excel("lucia_validation.xlsx")

# %%
lucia_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4977 entries, 0 to 4976
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   texts   4977 non-null   object
# dtypes: object(1)
# memory usage: 39.0+ KB

# %%
len(eric_sentences)
# Out:
# 1982

# %%
len(lucia_sentences)
# Out:
# 2068

# %%
len(sada_sentences)
# Out:
# 2995

# %%
eric_validation = []
eric_validation = pd.DataFrame((lucia_sentences + sada_sentences), columns=['texts'])
eric_validation = shuffle(eric_validation)
eric_validation = eric_validation.reset_index(drop=True)
eric_validation.head()
# Out:
#                                                texts
# 0  Over an old crazy bedstead was thrown a squali...
# 1  They are acting girls, singing girls, dancing ...
# 2        The season of the year was uncommonly fine;
# 3  He stopped frequently to look at them, and he ...
# 4  Laurence Aspinall, boarding with a master, had...

# %%
eric_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5063 entries, 0 to 5062
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   texts   5063 non-null   object
# dtypes: object(1)
# memory usage: 39.7+ KB

# %%
eric_validation.to_excel("eric_validation.xlsx")

# %%
claudia_validation = pd.DataFrame((lucia_sentences + sada_sentences + eric_sentences), columns=['texts'])
claudia_validation = shuffle(claudia_validation)
claudia_validation = claudia_validation.reset_index(drop=True)
claudia_validation.head()
# Out:
#                                                texts
# 0  Her hand was cool and soft and firm, the most ...
# 1  But, as he wanted the mother's wealth, he reso...
# 2  It was just like what the schoolmaster had bee...
# 3  It was a great black cavern with a red heart t...
# 4                Humphrey was delighted at the idea.

# %%
claudia_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7045 entries, 0 to 7044
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   texts   7045 non-null   object
# dtypes: object(1)
# memory usage: 55.2+ KB

# %%
claudia_validation.to_excel("claudia_validation.xlsx")
